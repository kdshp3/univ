# %% [markdown]
# # 1)
# <pre>
# select concat(first_name,' ',last_name) as Name, job_id as Job, salary, salary*12+100 as Increased_Ann_Salary, (salary+100)*12 as Increased_Salary from employees
# </pre>
# ![image.png](attachment:image.png)
# # 2)
# <pre>
# select concat(last_name, ': 1 Year Salary = &#36;', salary*12) as 1_Year_Salary from employees
# </pre>
# ![image-2.png](attachment:image-2.png)
# # 3)
# <pre>
# select distinct department_id, job_id from employees
# </pre>
# ![image-3.png](attachment:image-3.png)
# # 4)
# <pre>
# select last_name as Name, employee_id, hire_date from employees where hire_date between '1995-05-20' and '1996-05-20' order by hire_date
# </pre>
# ![image-4.png](attachment:image-4.png)
# # 5)
# <pre>
# select concat(first_name, ' ', last_name) as Name, salary, job_id, commission_pct from employees where commission_pct is not null order by salary desc, commission_pct desc
# </pre>
# ![image-5.png](attachment:image-5.png)
# # 6)
# <pre>
# select concat(upper(left(first_name, '1')), substring(first_name, '2'), ' ',upper(left(last_name, '1')), substring(last_name, '2'), ' is a ', upper(job_id)) as Employee_JOBs from employees where last_name like '%s'
# </pre>
# ![image-6.png](attachment:image-6.png)
# # 7)
# <pre>
# select concat(first_name, ' ', last_name) as Name, salary, salary*12 as Annual_salary, IF(commission_pct is null, 'Salary only', 'Salary + Commission') as 'commission_?' from employees order by Annual_salary desc
# </pre>
# ![image-7.png](attachment:image-7.png)
# # 8)
# <pre>
# select concat(first_name,' ',last_name) as Name, hire_date, date_format(hire_date, '%W') as Weekday from employees order by dayofweek(hire_date);
# </pre>
# ![image-9.png](attachment:image-9.png)
# # 9)
# <pre>
# select department_id, concat('&#36;', format(sum(salary),0)) as Sum_Salary, concat('&#36;', format(avg(salary),0)) as Avg_Salary, concat('&#36;', format(max(salary),0)) as Max_Salary, concat('&#36;', format(min(salary),0)) as Min_Salary from employees where department_id is not null group by department_id order by department_id;
# </pre>
# ![image-10.png](attachment:image-10.png)
# # 10)
# <pre>
# select job_id, avg(salary) as Avg_Salary from employees where upper(job_id) not like'%CLERK%'group by job_id having Avg_Salary > 10000 order by Avg_Salary desc;
# </pre>
# ![image-11.png](attachment:image-11.png)
